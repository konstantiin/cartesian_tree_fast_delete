# %%
import json
import matplotlib.pyplot as plt

# %%
with open("data.json") as f:
    data = json.load(f)

# %%
figsize = (30, 20)

# %%
plt.figure(figsize = figsize)
plt.plot(data["my_insert"])
plt.show()

# %%
plt.figure(figsize = figsize)
plt.plot(data["std_insert"])
plt.show()

# %%
plt.figure(figsize = figsize)
plt.plot(data["my_erase"])
plt.show()

# %%
plt.figure(figsize = figsize)
plt.plot(data["std_erase"])
plt.show()

# %%
plt.figure(figsize = figsize)
plt.plot(data["my_min_erase"])
plt.show()

# %%
plt.figure(figsize = figsize)
plt.plot(data["std_min_erase"])
plt.show()

# %%
plt.figure(figsize = figsize)
plt.plot(data["random_my"])
plt.show()

# %%
plt.figure(figsize = figsize)
plt.plot(data["random_std"])
plt.show()

# %%
sum(data["random_std"])
# Out:
# 47513300

# %%
sum(data["random_my"])
# Out:
# 19536600
